# %%
### This notebook loads the file containing the agent's uncertainties over an episode produced by the

# %%
import pickle
import torch
import time

import gym
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pickle.load(open('uncertainties','rb'))

# %%
plt.scatter(data[1][0],0.01,c='r')
plt.scatter(data[1][1],0.01,c='r')
plt.scatter(data[1][2],0.01,c='r')
plt.scatter(data[1][3],0.01,c='r')
plt.scatter(len(data[0]),0.01,c='r')
data = np.array(data[0])
plt.plot(data/10)
plt.title("Agent uncertainty", size=20)
plt.xlabel("Agent Steps", size=20)
plt.ylabel("Uncertainty", size=20)
plt.axis([0,2000,-0,0.8])
plt.show()
